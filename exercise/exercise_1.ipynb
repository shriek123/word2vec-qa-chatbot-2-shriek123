# %% [markdown]
# # Word2vec model

# %%
import gensim
import nltk

# %%
text_data = """Machine learning is a branch of artificial intelligence and computer science. 
Machine learning focuses on the use of data and algorithms to imitate the way that humans learn."""

# Download the punkt tokenizer
nltk.download("punkt")

# Split the text into sentences
sentences = nltk.sent_tokenize(text_data)

# Convert sentences to words
sentences = [gensim.utils.simple_preprocess(s) for s in sentences]
# Out:
# [nltk_data] Downloading package punkt to /home/vscode/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
sentences
# Out:
# [['machine',
#   'learning',
#   'is',
#   'branch',
#   'of',
#   'artificial',
#   'intelligence',
#   'and',
#   'computer',
#   'science'],
#  ['machine',
#   'learning',
#   'focuses',
#   'on',
#   'the',
#   'use',
#   'of',
#   'data',
#   'and',
#   'algorithms',
#   'to',
#   'imitate',
#   'the',
#   'way',
#   'that',
#   'humans',
#   'learn']]

# %% [markdown]
# From the text corpus, we can train the word2vec model using gensim. We can set different parameters for the word2vec model.

# %%
# Build the word2vec model
w2v = gensim.models.Word2Vec(
    sentences=sentences,  # input data
    vector_size=128,  # size of the vectors
    window=5,  # window size
    min_count=1,  # minimum count of words
    epochs=3,  # number of iterations
    hs=0,  # Turn off hierarchical softmax and use negative sampling
    sg=1,  # Use skip-gram instead of CBOW
)

# %%
vocab = list(w2v.wv.key_to_index)
emb = w2v.wv[vocab]

# %%
emb.shape
# Out:
# (22, 128)

# %% [markdown]
# After training process, we will get a high-dimensional vector space for text corpus. We can project this vector space into 2D or 3D to further observe the embedding relationship.

# %%
import umap
import matplotlib.pyplot as plt

# Reduce dimensionality
reducer = umap.UMAP(n_components=3, random_state=42, n_neighbors=5, metric="cosine")
xyz = reducer.fit_transform(emb)

# Create a 3D scatter plot with Seaborn
fig = plt.figure(figsize=(9, 9))
ax = fig.add_subplot(111, projection='3d')
x=xyz[:, 0]
y=xyz[:, 1]
z=xyz[:, 2]
ax.scatter(x, y, z, c=z, cmap='viridis', marker='o')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
for i, c in enumerate(vocab):
    ax.text(xyz[i,0],xyz[i,1],xyz[i,2],  '%s' % c, size=10)
plt.show()
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/umap/umap_.py:1943: UserWarning: n_jobs value -1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %% [markdown]
# # Word2vec Question and Answer Chatbot Application

# %% [markdown]
# In this exercise, we will create a Q-A chatbot only based on question search.

# %% [markdown]
# ## Component 1: data preparation

# %%
import pandas as pd

df = pd.read_csv("../data/Question_Answer_Dataset_v1.2_S10.csv")
df.head()
# Out:
#        ArticleTitle                                           Question  \
# 0  Alessandro_Volta     Was Alessandro Volta a professor of chemistry?
# 1  Alessandro_Volta  Did Alessandro Volta invent the remotely opera...
# 2  Alessandro_Volta     Was Alessandro Volta taught in public schools?
# 3  Alessandro_Volta                    Who did Alessandro Volta marry?
# 4  Alessandro_Volta          What did Alessandro Volta invent in 1800?
#
#                                               Answer DifficultyFromQuestioner  \
# 0  Alessandro Volta was not a professor of chemis...                     easy
# 1  Alessandro Volta did invent the remotely opera...                     easy
# 2                Volta was taught in public schools.                     easy
# 3         Alessandro Volta married Teresa Peregrini.                   medium
# 4  In 1800, Alessandro Volta invented the voltaic...                   medium
#
#   DifficultyFromAnswerer    ArticleFile
# 0                   easy  data/set4/a10
# 1                   easy  data/set4/a10
# 2                   easy  data/set4/a10
# 3                 medium  data/set4/a10
# 4                   easy  data/set4/a10

# %%
df.isna().sum()
# Out:
# ArticleTitle                0
# Question                    0
# Answer                      0
# DifficultyFromQuestioner    0
# DifficultyFromAnswerer      0
# ArticleFile                 0
# dtype: int64

# %%
df["Answer"][12]
# Out:
# 'Napoleon'

# %%
df["Answer"][14]
# Out:
# '1819'

# %% [markdown]
# In our data, there are both text and numbers. We need to generate a set of corpus including both of them. Based on this, we cannot use gensim.utils.simple_preprocess to prepare corpus. Here, we will use regular expression.

# %%
import re

# initializing string
test_str = "Gfg, is best : for ! Geeks ;? 123 a 9..."

# printing original string
print("The original string is : " + test_str)

# Removing punctuations in string
res = re.sub(r'[^\w\s]', '', test_str)
# Replace all sequences of two or more spaces with a single space.
res = re.sub(' +', ' ', res)

# printing result
print("The string after punctuation filter : ", res.strip().split(" "))
# Out:
# The original string is : Gfg, is best : for ! Geeks ;? 123 a 9...
# The string after punctuation filter :  ['Gfg', 'is', 'best', 'for', 'Geeks', '123', 'a', '9']

# %% [markdown]
# ## Component 2: word2vec model training

# %%
# train word2vec model with all questions

# Split the text into sentences
sentences = df["Question"].to_list() + df["Answer"].to_list()

def token(text):
  # Removing punctuations in string
  res = re.sub(r'[^\w\s]', '', text)
  # Replace all sequences of two or more spaces with a single space.
  res = re.sub(' +', ' ', res)
  # lower case
  res = res.lower()
  return res.strip().split(" ")

# Convert sentences to words
sentences = [token(text) for text in sentences]

# %%
w2v = gensim.models.Word2Vec(
    sentences=sentences,  # input data
    vector_size=128,  # size of the vectors
    window=5,  # window size
    min_count=1,  # minimum count of words
    epochs=3,  # number of iterations
    hs=0,  # Turn off hierarchical softmax and use negative sampling
    sg=1,  # Use skip-gram instead of CBOW
)

# %%
w2v.save("../data/w2v.model")

# %%
w2v.save("../data/w2v-advanced.model")

# %% [markdown]
# __Hint for assignment_1__: Please rename your trained word2vec model as "w2v-advanced.model", when you save it for assignment_1.py. Otherwise, the chatbot application will prompt error or give wrong responses.

# %% [markdown]
# ## Component 3: generate embeddings

# %%
import numpy as np

# calculate sentence vector for each sentence
def sentence_vec(sent):
    # Filter out terms that are not in the vocabulary from the question sentence
    tm_voc = [tm for tm in sent if tm in w2v.wv]
    # Get the embedding of the characters
    emb = np.vstack([w2v.wv[tm] for tm in tm_voc])
    # Calculate the vectors of each included word to get the vector of the question
    ave_vec = np.mean(emb, axis=0)
    return ave_vec

# %%
ques_vec = [sentence_vec(sent) for sent in sentences[:df.shape[0]]]
ques_vec = np.array(ques_vec)
ans_vec = [sentence_vec(sent) for sent in sentences[df.shape[0]:]]
# ans_vec=np.array(ans_vec)
np.savez("../data/vector.npz", x=ques_vec,y=ans_vec)

# %%
# ques_vec.shape
ans_vec
# Out:
# [array([ 0.01694856, -0.03937205,  0.04145937,  0.03405623,  0.0286789 ,
#         -0.01657102, -0.01280819,  0.02628045, -0.00011611,  0.04696872,
#          0.03609541, -0.00324906, -0.02464804, -0.04058367,  0.03752935,
#          0.05637488, -0.04300416,  0.02860965, -0.04042023,  0.04870375,
#          0.02167218,  0.0070035 , -0.03795601, -0.07354122, -0.06808481,
#          0.01458753, -0.0432702 ,  0.02419629,  0.00451201,  0.00487938,
#         -0.03117253, -0.00481081,  0.00615847,  0.02570627, -0.01545864,
#          0.04360689,  0.05155493, -0.00571631,  0.02855218, -0.0101997 ,
#         -0.026265  ,  0.07474027, -0.01704057, -0.022864  ,  0.05816022,
#          0.00201449, -0.03827276,  0.01144473, -0.00829392,  0.02407951,
#          0.05298002,  0.00563168,  0.02038955,  0.02442639, -0.01590675,
#         -0.00152813,  0.03875876, -0.02568954, -0.0409891 ,  0.02736821,
#         -0.0346095 , -0.00505228,  0.02270502, -0.02574457,  0.03720168,
#         -0.00117178,  0.02359111, -0.01207065, -0.00499056, -0.03897164,
#         -0.03651942, -0.03729311, -0.07402378, -0.05693889,  0.01672982,
#         -0.04699187, -0.03901884,  0.0180712 , -0.02033099,  0.07366592,
#         -0.03517254, -0.0373175 ,  0.05759288,  0.09163834,  0.03661   ,
#          0.0211229 ,  0.03638599, -0.06440812,  0.02405706,  0.02058099,
#         -0.01505137, -0.03487867,  0.00160799, -0.01208851,  0.06440952,
#          0.00315718, -0.05470034, -0.05846199, -0.00883298, -0.00779748,
#         -0.0565359 , -0.0044493 , -0.00379013,  0.02158334,  0.0048754 ,
#          0.01769091,  0.01109701,  0.02243087,  0.00742658, -0.03869021,
#          0.03374669, -0.0367611 ,  0.01033759,  0.01479026, -0.04208981,
#         -0.03137657,  0.01657165,  0.02195279,  0.03957723,  0.00890424,
#         -0.0363346 , -0.04362885, -0.03351457,  0.0307359 , -0.02340549,
#         -0.01226055, -0.02241665, -0.01752957], dtype=float32),
#  array([ 0.01385697, -0.02822215,  0.02863564,  0.02539177,  0.01714562,
#         -0.01348945, -0.00708967,  0.0203397 , -0.00193842,  0.03122105,
#          0.02293112, -0.00496924, -0.01548654, -0.02676571,  0.02829097,
#          0.04199331, -0.03070903,  0.02068342, -0.03099068,  0.03178091,
#          0.01690135,  0.00503422, -0.0293351 , -0.0538134 , -0.04576188,
#          0.00838055, -0.03114981,  0.01829832,  0.00249553,  0.00202762,
#         -0.02322504, -0.00394361,  0.00600227,  0.01829264, -0.01036337,
#          0.03045709,  0.03833057, -0.00381568,  0.02037762, -0.00656067,
#         -0.02092255,  0.05230393, -0.01186592, -0.01459814,  0.04256885,
#          0.00031212, -0.02626208,  0.00960395, -0.00505751,  0.0174381 ,
#          0.03576605,  0.00149117,  0.01447105,  0.01835624, -0.00984842,
#         -0.00129433,  0.02742925, -0.01794495, -0.03223602,  0.02029643,
#         -0.02426235, -0.00572565,  0.01388563, -0.02219734,  0.02494323,
#         -0.00088931,  0.01529099, -0.00743712, -0.00426257, -0.02583416,
#         -0.0247349 , -0.02423718, -0.05450004, -0.04144299,  0.01246493,
#         -0.03557946, -0.02512121,  0.01259683, -0.01302417,  0.04854598,
#         -0.02491022, -0.02831213,  0.04094159,  0.06406499,  0.02504491,
#          0.01859797,  0.02660502, -0.04613974,  0.01537163,  0.01622967,
#         -0.01483793, -0.02390445,  0.00489287, -0.00569738,  0.04547356,
#          0.00428212, -0.03912981, -0.04294043, -0.00788897, -0.0052315 ,
#         -0.03957787, -0.0030254 , -0.00162203,  0.01300442,  0.0023021 ,
#          0.01368443,  0.00783753,  0.01887046,  0.00381524, -0.03053434,
#          0.02418251, -0.02566051,  0.00929965,  0.0107834 , -0.0296951 ,
#         -0.02458875,  0.01126459,  0.01308487,  0.02454212,  0.00595073,
#         -0.02566471, -0.03234481, -0.02353986,  0.01966872, -0.01353341,
#         -0.0061319 , -0.01566971, -0.01007575], dtype=float32),
#  array([ 0.01011974, -0.02863173,  0.0342135 ,  0.02685492,  0.02298404,
#         -0.01134016, -0.01186427,  0.02120855,  0.00189969,  0.03560852,
#          0.0317099 , -0.00223487, -0.01713426, -0.03423109,  0.02775162,
#          0.04509442, -0.03076535,  0.02072208, -0.03398878,  0.03902689,
#          0.0170397 ,  0.00449578, -0.0275533 , -0.061237  , -0.05429626,
#          0.01112499, -0.03394882,  0.02075941,  0.00051829,  0.00612749,
#         -0.02852703, -0.0047485 ,  0.00410413,  0.01861209, -0.01057126,
#          0.032455  ,  0.04053202, -0.00333851,  0.02346379, -0.00437459,
#         -0.02231462,  0.05950852, -0.01461912, -0.01850538,  0.04270127,
#          0.00046022, -0.02302924,  0.00699753, -0.00730168,  0.02067043,
#          0.04339664,  0.00283436,  0.01461551,  0.01837897, -0.01254173,
#         -0.00126016,  0.0320053 , -0.01993275, -0.03412778,  0.02242197,
#         -0.02584668, -0.0052123 ,  0.01826026, -0.02267364,  0.03073763,
#         -0.0041638 ,  0.01629239, -0.00684276, -0.00494291, -0.03254532,
#         -0.02700734, -0.03043965, -0.05898439, -0.04636949,  0.01332687,
#         -0.04066963, -0.02894066,  0.01462513, -0.01661793,  0.05406563,
#         -0.02495953, -0.02928195,  0.04975278,  0.07239489,  0.02754132,
#          0.02128009,  0.02791622, -0.04870139,  0.01518217,  0.01578148,
#         -0.01149328, -0.02698815,  0.00198645, -0.00971268,  0.05077851,
#          0.00044526, -0.04144132, -0.04607628, -0.00854122, -0.00800689,
#         -0.04520394, -0.00517463, -0.00277759,  0.01660987,  0.00235004,
#          0.01476421,  0.0091781 ,  0.01837139,  0.00638222, -0.03273072,
#          0.02551246, -0.0294487 ,  0.01019116,  0.01167672, -0.03174465,
#         -0.02841392,  0.0117082 ,  0.01729382,  0.02907629,  0.00468111,
#         -0.02863935, -0.03762802, -0.02343896,  0.02481282, -0.01744816,
#         -0.00753699, -0.01626862, -0.01122405], dtype=float32),
#  array([ 0.00498337, -0.01348985,  0.01228963,  0.008608  ,  0.00922694,
#         -0.00660001, -0.00341315,  0.00593729,  0.00146617,  0.01077587,
#          0.0127812 , -0.00294422, -0.00271371, -0.01377934,  0.00956721,
#          0.01927979, -0.0103986 ,  0.00516672, -0.0126701 ,  0.01576963,
#          0.00370226,  0.0016744 , -0.01057738, -0.02129168, -0.01688278,
#          0.00187171, -0.01149904,  0.00533095,  0.00025685,  0.0024449 ,
#         -0.0060239 , -0.00105485,  0.00338711,  0.00673139, -0.00540572,
#          0.01655226,  0.0135058 ,  0.00041554,  0.00680925, -0.00343303,
#         -0.0063915 ,  0.01999194, -0.00389546, -0.00749489,  0.01484434,
#         -0.00095056, -0.0077852 ,  0.00489983, -0.00116039,  0.00296232,
#          0.01250601,  0.00225546,  0.00465397,  0.00951082, -0.00537679,
#          0.00158538,  0.00677233, -0.00753699, -0.01422952,  0.01173224,
#         -0.01066603,  0.00133791,  0.00838648, -0.01046791,  0.00900639,
#         -0.00086676,  0.00429171, -0.00628451, -0.00440774, -0.00875441,
#         -0.00721983, -0.00900271, -0.02167083, -0.01380049,  0.00861497,
#         -0.01575003, -0.01124659,  0.0019025 , -0.00348115,  0.02119604,
#         -0.01109897, -0.00729288,  0.01609527,  0.02423963,  0.01096367,
#          0.00856673,  0.00947709, -0.01532699,  0.00782471,  0.00583363,
#         -0.00549145, -0.01004873,  0.00675851, -0.00513626,  0.01848759,
#          0.00457156, -0.01740174, -0.01387048, -0.00623305, -0.00015095,
#         -0.01934589, -0.0039222 ,  0.00377136,  0.00812622,  0.00016454,
#          0.00572881,  0.00536908,  0.00717988, -0.00268186, -0.01192215,
#          0.00542565, -0.00947016,  0.00876874,  0.00556767, -0.00935863,
#         -0.01265508,  0.005116  ,  0.00655247,  0.00634084, -0.0014268 ,
#         -0.00938734, -0.01365691, -0.00902335,  0.00963203, -0.00451539,
#         -0.00561664, -0.00599827, -0.00132994], dtype=float32),
#  array([ 0.01592671, -0.03609755,  0.03549753,  0.03235835,  0.02287271,
#         -0.01503455, -0.0122366 ,  0.02157358, -0.00144818,  0.03872178,
#          0.03156552, -0.005866  , -0.02029458, -0.0352185 ,  0.03078171,
#          0.0492755 , -0.03552889,  0.02551127, -0.03947277,  0.03840479,
#          0.02041067,  0.00676112, -0.03163994, -0.06240531, -0.05653772,
#          0.01001214, -0.03930185,  0.01929163,  0.00095728,  0.00356757,
#         -0.02690774, -0.00521034,  0.00738015,  0.02212804, -0.01343966,
#          0.03711185,  0.04445068, -0.00644586,  0.02546685, -0.00701685,
#         -0.02244158,  0.06356484, -0.0135696 , -0.01819687,  0.04790409,
#          0.00217928, -0.0304691 ,  0.01201429, -0.00907306,  0.01991614,
#          0.04213173,  0.00366656,  0.0170109 ,  0.02456021, -0.01316439,
#          0.00144956,  0.03385496, -0.02252133, -0.03718279,  0.02322096,
#         -0.02877447, -0.00378247,  0.0216267 , -0.02525681,  0.02858939,
#         -0.00136421,  0.02043394, -0.00988467, -0.00681244, -0.03113111,
#         -0.02965595, -0.03121932, -0.06489793, -0.05317086,  0.01642393,
#         -0.04090852, -0.03311021,  0.01430192, -0.01755189,  0.06147802,
#         -0.028615  , -0.03174784,  0.04983862,  0.0782086 ,  0.03087902,
#          0.01890737,  0.02859479, -0.05616243,  0.01630653,  0.01874246,
#         -0.01407797, -0.03036081,  0.00248451, -0.00970985,  0.0565216 ,
#          0.00068073, -0.04695497, -0.04970459, -0.00765285, -0.00637807,
#         -0.04635825, -0.00635359, -0.00122765,  0.0192104 ,  0.00514004,
#          0.01617732,  0.01013748,  0.02193331,  0.0055044 , -0.03491508,
#          0.02776801, -0.03366172,  0.01190026,  0.0152302 , -0.03362478,
#         -0.02806032,  0.0172897 ,  0.01888974,  0.03397254,  0.00497571,
#         -0.03412475, -0.04059871, -0.02721195,  0.02627227, -0.0187478 ,
#         -0.00931056, -0.02182911, -0.01440898], dtype=float32),
#  array([ 0.01958399, -0.04209065,  0.04252278,  0.04271184,  0.03009438,
#         -0.02005545, -0.00930618,  0.03118119, -0.00309604,  0.04919633,
#          0.04142484, -0.00618454, -0.02709863, -0.04314257,  0.04386643,
#          0.06251033, -0.04394567,  0.02852895, -0.04642817,  0.05192016,
#          0.02570351,  0.00972459, -0.04266457, -0.0844106 , -0.07250606,
#          0.01563294, -0.04870282,  0.03168937,  0.00455964,  0.00223769,
#         -0.0369527 , -0.00530882,  0.0081621 ,  0.02712005, -0.01566644,
#          0.04814815,  0.0596735 , -0.0054935 ,  0.03177116, -0.01060421,
#         -0.03106192,  0.08299497, -0.01719084, -0.0246984 ,  0.06356785,
#          0.00185387, -0.0417717 ,  0.01367586, -0.00918621,  0.03037862,
#          0.05734622,  0.00649831,  0.02140745,  0.02651493, -0.01628959,
#         -0.00349545,  0.04396934, -0.0298211 , -0.04750742,  0.02821386,
#         -0.03790087, -0.00662773,  0.0272324 , -0.03239746,  0.041136  ,
#         -0.00295384,  0.02436773, -0.00919457, -0.00784802, -0.04231789,
#         -0.03528526, -0.03858155, -0.08261875, -0.06335989,  0.02075301,
#         -0.05300966, -0.04116986,  0.01694372, -0.02288319,  0.07687107,
#         -0.0334568 , -0.04247907,  0.06378384,  0.10068364,  0.0397492 ,
#          0.02575578,  0.04013179, -0.07359072,  0.02518702,  0.02509466,
#         -0.01711144, -0.03940677,  0.00402023, -0.0141981 ,  0.07195233,
#          0.00421204, -0.0597749 , -0.06742191, -0.0115132 , -0.01040977,
#         -0.05877338, -0.00496033, -0.00364973,  0.02493914,  0.00649386,
#          0.02103895,  0.0127273 ,  0.02869698,  0.00954088, -0.04426925,
#          0.03802021, -0.04082741,  0.01193346,  0.01758542, -0.04585012,
#         -0.03571588,  0.0243421 ,  0.02138466,  0.04304686,  0.00749081,
#         -0.04308608, -0.04784961, -0.03634643,  0.03423418, -0.02360841,
#         -0.0105309 , -0.02591313, -0.01489827], dtype=float32),
#  array([ 0.01739704, -0.04044579,  0.04360601,  0.03871244,  0.0277232 ,
#         -0.01971862, -0.01420191,  0.03001469, -0.00363957,  0.04748473,
#          0.0384908 , -0.00537104, -0.02483484, -0.04450399,  0.0400991 ,
#          0.06149409, -0.04333378,  0.0290631 , -0.04520565,  0.0482982 ,
#          0.02335808,  0.00917138, -0.04025477, -0.08005123, -0.0689903 ,
#          0.01543481, -0.0464944 ,  0.02761852,  0.00434663,  0.00395316,
#         -0.03360519, -0.00461688,  0.00667736,  0.02583189, -0.0128086 ,
#          0.04368202,  0.05824596, -0.00739039,  0.02913013, -0.01051494,
#         -0.02552019,  0.07854377, -0.01785723, -0.0236203 ,  0.05974986,
#          0.00489422, -0.03730465,  0.01390972, -0.01020766,  0.02385066,
#          0.05352792,  0.00501397,  0.02018775,  0.0267681 , -0.01346733,
#         -0.00255335,  0.04095379, -0.02610907, -0.04587622,  0.02833013,
#         -0.03699241, -0.00670758,  0.02615643, -0.0305921 ,  0.03987916,
#         -0.00336582,  0.02470682, -0.01187509, -0.0073391 , -0.04022041,
#         -0.03734558, -0.03993192, -0.07978874, -0.06097639,  0.01932911,
#         -0.047727  , -0.04049211,  0.01660637, -0.02221358,  0.07310253,
#         -0.03703265, -0.04053999,  0.06153415,  0.09579915,  0.03966031,
#          0.02522336,  0.03695121, -0.06956688,  0.02182485,  0.02249373,
#         -0.01571328, -0.03644852,  0.00278198, -0.01183341,  0.06767572,
#          0.00503618, -0.05883494, -0.06050146, -0.00941086, -0.01006793,
#         -0.0569401 , -0.00608817, -0.00107777,  0.02390892,  0.0051581 ,
#          0.02131572,  0.01365605,  0.02756176,  0.0067707 , -0.04206772,
#          0.0349292 , -0.03914384,  0.0124522 ,  0.01695959, -0.04163023,
#         -0.03481254,  0.01819639,  0.02155238,  0.04122168,  0.00753224,
#         -0.04060592, -0.04670755, -0.03255925,  0.03324856, -0.02531699,
#         -0.0109565 , -0.02414675, -0.01678268], dtype=float32),
#  array([ 0.01716749, -0.03933583,  0.04181103,  0.03647476,  0.02647107,
#         -0.01798046, -0.01159848,  0.02809565, -0.00470201,  0.04295012,
#          0.03435331, -0.00368674, -0.02463643, -0.04014631,  0.03740719,
#          0.05576941, -0.04064755,  0.02557022, -0.04088729,  0.04565113,
#          0.02254923,  0.00799882, -0.03682826, -0.07603747, -0.06488763,
#          0.0145897 , -0.04608012,  0.02615084,  0.00562635,  0.00364552,
#         -0.03359688, -0.00411039,  0.00801538,  0.02477296, -0.01330575,
#          0.04206154,  0.05265123, -0.00427975,  0.02873317, -0.00852998,
#         -0.02523816,  0.07189312, -0.0166409 , -0.02282678,  0.05535526,
#          0.00170593, -0.03478574,  0.01282047, -0.00786585,  0.02364953,
#          0.0505271 ,  0.00529975,  0.0191184 ,  0.02610814, -0.01485416,
#         -0.00072013,  0.03888261, -0.02387075, -0.04113742,  0.02634509,
#         -0.03351595, -0.00584676,  0.02311084, -0.0272305 ,  0.0357132 ,
#         -0.00061742,  0.02372915, -0.01089261, -0.00498162, -0.03864419,
#         -0.03122643, -0.03667159, -0.07654778, -0.05982109,  0.01748393,
#         -0.04713527, -0.03689913,  0.01480082, -0.01877818,  0.06774047,
#         -0.03209246, -0.03693433,  0.05936858,  0.09015232,  0.03493537,
#          0.02345971,  0.03619568, -0.06305423,  0.02049485,  0.02147734,
#         -0.01471614, -0.03450484,  0.00506233, -0.00887085,  0.06471242,
#          0.00370269, -0.0538838 , -0.05767101, -0.00723428, -0.00864737,
#         -0.05430995, -0.00438305, -0.00212257,  0.02087135,  0.00675404,
#          0.01630116,  0.0133168 ,  0.02281823,  0.00690513, -0.04096243,
#          0.03211576, -0.03625676,  0.0127322 ,  0.01483241, -0.04072944,
#         -0.03229292,  0.01802302,  0.02167608,  0.03900341,  0.00883861,
#         -0.03912626, -0.04445191, -0.03158598,  0.02984581, -0.02236315,
#         -0.01049199, -0.02116672, -0.01584888], dtype=float32),
#  array([ 0.0177944 , -0.03989962,  0.04079482,  0.03406006,  0.02709155,
#         -0.01701588, -0.0105458 ,  0.02580784, -0.00325038,  0.04550771,
#          0.03636261, -0.00232799, -0.0239563 , -0.04037353,  0.03941236,
#          0.05580015, -0.04186831,  0.02818255, -0.0393607 ,  0.04672997,
#          0.02156231,  0.00726269, -0.03669053, -0.0735935 , -0.06362166,
#          0.01317541, -0.0440946 ,  0.02489628,  0.00491476,  0.00298784,
#         -0.031536  , -0.0032253 ,  0.00662291,  0.02317778, -0.01534529,
#          0.04112921,  0.05131268, -0.00619874,  0.02930095, -0.01024322,
#         -0.02447024,  0.07426219, -0.01724253, -0.02133515,  0.05758014,
#          0.00104022, -0.03675939,  0.01241247, -0.00852183,  0.02306862,
#          0.05146525,  0.00428438,  0.02047016,  0.02506412, -0.0132589 ,
#         -0.00169875,  0.038373  , -0.02519476, -0.04280385,  0.02646046,
#         -0.03481039, -0.00609597,  0.02417387, -0.02606122,  0.03645463,
#         -0.0016356 ,  0.02040605, -0.01041552, -0.0068136 , -0.03842768,
#         -0.03393763, -0.03560289, -0.07379544, -0.05692439,  0.01773228,
#         -0.04511893, -0.03719417,  0.01819172, -0.0191119 ,  0.06884775,
#         -0.03119577, -0.03900945,  0.05543903,  0.08973707,  0.03514563,
#          0.02234043,  0.0358304 , -0.06485464,  0.02140746,  0.02272305,
#         -0.01385527, -0.03506763,  0.00393403, -0.01322026,  0.06336297,
#          0.00240493, -0.05312113, -0.05866823, -0.00744391, -0.00872826,
#         -0.05590823, -0.00444853, -0.0042225 ,  0.02081678,  0.00428631,
#          0.01771686,  0.01319125,  0.02268266,  0.00745004, -0.03979229,
#          0.03357829, -0.03645037,  0.01068674,  0.01470143, -0.04092855,
#         -0.03221936,  0.01846187,  0.0218521 ,  0.03941134,  0.01012467,
#         -0.03845572, -0.0420815 , -0.03199262,  0.02862314, -0.0201703 ,
#         -0.01002887, -0.02433985, -0.01605563], dtype=float32),
#  array([ 9.42969602e-03, -1.19439624e-02,  1.48304384e-02,  1.42709650e-02,
#          5.10896649e-03, -5.22695761e-03, -3.77514225e-05,  1.22871995e-03,
#          7.15945894e-03,  3.19339894e-03,  3.02918954e-03,  1.03010645e-03,
#         -9.38105455e-04, -1.36747705e-02,  1.17415823e-02,  2.04545707e-02,
#         -1.47647914e-02,  1.64676830e-03, -1.32296328e-02,  8.32361635e-03,
#          6.98685925e-03,  9.53387842e-03, -4.43536462e-03, -1.75772179e-02,
#         -1.34487543e-02,  1.00997509e-02, -3.37762432e-03,  1.04563329e-02,
#          6.19692868e-03, -5.34859160e-03, -1.09900562e-02, -5.46655245e-03,
#          5.98693080e-03,  3.67922196e-03, -9.89204366e-03,  1.57802738e-02,
#          1.93882789e-02, -4.09608847e-03,  1.41899278e-02, -2.94416700e-03,
#         -8.72108154e-03,  1.72688477e-02, -3.51782027e-03, -7.63557432e-03,
#          1.58426035e-02,  5.22042997e-03, -3.15360702e-03, -4.22055833e-03,
#         -4.02431702e-03,  1.26459741e-03,  1.79705303e-02,  6.01415802e-03,
#          1.34999782e-03,  7.83223193e-03, -8.01484659e-03, -5.75621147e-04,
#          1.65769421e-02, -7.09300069e-03, -1.45615283e-02,  2.58827698e-04,
#         -1.05915898e-02, -2.42378423e-03,  8.50096159e-03,  1.41210249e-03,
#          6.49627810e-03,  7.67567311e-04,  1.25230728e-02, -1.44324207e-03,
#         -8.65801354e-04, -1.46213558e-03, -9.63685685e-04, -2.79214373e-03,
#         -2.29102820e-02, -5.42768743e-03,  8.61262530e-03, -3.92649090e-03,
#         -1.06081869e-02,  6.78084139e-03,  6.71187590e-05,  1.31860599e-02,
#         -2.40283646e-03, -7.11876480e-03,  2.08804514e-02,  1.86920613e-02,
#          6.75026840e-03,  1.03737963e-02,  1.32125127e-03, -2.10877787e-02,
#          7.30402535e-05,  4.88562742e-03, -5.68448566e-03, -3.24407709e-03,
#          7.61769200e-03, -3.67536093e-03,  1.59850772e-02,  2.02194648e-03,
#         -1.39789796e-02, -2.04276722e-02,  3.76635441e-03, -5.69170760e-03,
#         -8.75409134e-03,  5.85080311e-03,  1.38557039e-03,  7.48091005e-03,
#          4.28607827e-03,  2.33971397e-03,  5.05615165e-03,  6.54757349e-03,
#          6.53455267e-03, -5.57036279e-03,  9.14369710e-03, -4.55318717e-03,
#         -4.36464045e-03,  8.56014900e-03, -2.36343569e-03, -1.05272550e-02,
#          6.00578263e-03,  8.18115077e-04,  1.03766844e-02,  4.55409568e-03,
#         -3.02283047e-03, -9.80125647e-03, -5.58270374e-03,  8.02579429e-03,
#          1.17566751e-03, -6.78309985e-03, -1.01967268e-02, -6.24344265e-03],
#        dtype=float32),
#  array([ 1.53585561e-02, -2.48949919e-02,  2.73398869e-02,  1.28576765e-02,
#          1.77861825e-02, -6.45618711e-04, -1.22217005e-02,  6.83573494e-03,
#         -4.79353173e-03,  2.12111920e-02,  1.86758023e-02, -9.59818438e-03,
#         -1.98295135e-02, -1.97147857e-02,  1.46305505e-02,  2.28987690e-02,
#         -2.30956692e-02,  7.10436935e-03, -2.61121690e-02,  1.77317578e-02,
#          1.21788038e-02,  9.69405519e-04, -1.53783970e-02, -3.81949916e-02,
#         -3.69610488e-02,  1.24777090e-02, -2.79252864e-02,  9.09584016e-03,
#         -2.71199318e-03, -1.70203648e-03, -1.88789312e-02,  2.78673624e-03,
#          6.89103850e-04,  1.64989140e-02, -1.84351916e-03,  1.61462892e-02,
#          3.16869542e-02,  2.18120334e-03,  1.25318542e-02, -4.57241258e-05,
#         -8.76856968e-03,  3.39864902e-02, -1.35461409e-02, -8.79125111e-03,
#          2.87398510e-02, -3.38927656e-03, -1.12696160e-02,  2.31983257e-03,
#         -9.96820163e-03,  1.22182881e-02,  2.48653200e-02,  2.21581245e-03,
#          7.45293312e-03,  1.27884420e-02, -8.32542311e-03, -4.02738893e-04,
#          2.67467331e-02, -1.73375551e-02, -2.40784045e-02,  1.68891009e-02,
#         -1.18706990e-02, -7.66698644e-03,  2.04948261e-02, -7.25837657e-03,
#          1.66657940e-02, -1.84180611e-03,  1.47497663e-02, -8.16353410e-03,
#         -7.14774430e-03, -2.64160857e-02, -1.84907112e-02, -1.92698166e-02,
#         -3.62957120e-02, -3.18337120e-02,  8.03715829e-03, -2.25676931e-02,
#         -1.66086499e-02,  9.15659871e-03, -1.61162857e-02,  2.86314469e-02,
#         -1.67782512e-02, -1.46573177e-02,  3.11027765e-02,  3.98994870e-02,
#          1.33025507e-02,  1.74879804e-02,  1.64161455e-02, -2.92777661e-02,
#          6.93426142e-03,  1.86789352e-02, -1.30266258e-02, -1.58923361e-02,
#          6.17523401e-05, -1.20975198e-02,  3.07307914e-02,  6.06159330e-04,
#         -3.16521935e-02, -3.21645327e-02, -1.09570958e-02, -2.94580054e-03,
#         -2.01286860e-02, -4.42327792e-03, -3.42137995e-03,  1.38091752e-02,
#          1.01592382e-02,  5.40590752e-03,  5.22258924e-05,  1.09248897e-02,
#          1.18354857e-02, -2.11137403e-02,  1.17330393e-02, -2.10113078e-02,
#          1.33739514e-02,  1.86241511e-03, -2.57411152e-02, -9.35692899e-03,
#          2.84899632e-03,  1.34003880e-02,  2.17281263e-02,  1.00900549e-02,
#         -1.38369352e-02, -2.55307928e-02, -2.01793071e-02,  2.29104720e-02,
#         -1.03670610e-02, -1.52047316e-04, -2.00632699e-02,  7.27637962e-05],
#        dtype=float32),
#  array([ 1.53585561e-02, -2.48949919e-02,  2.73398869e-02,  1.28576765e-02,
#          1.77861825e-02, -6.45618711e-04, -1.22217005e-02,  6.83573494e-03,
#         -4.79353173e-03,  2.12111920e-02,  1.86758023e-02, -9.59818438e-03,
#         -1.98295135e-02, -1.97147857e-02,  1.46305505e-02,  2.28987690e-02,
#         -2.30956692e-02,  7.10436935e-03, -2.61121690e-02,  1.77317578e-02,
#          1.21788038e-02,  9.69405519e-04, -1.53783970e-02, -3.81949916e-02,
#         -3.69610488e-02,  1.24777090e-02, -2.79252864e-02,  9.09584016e-03,
#         -2.71199318e-03, -1.70203648e-03, -1.88789312e-02,  2.78673624e-03,
#          6.89103850e-04,  1.64989140e-02, -1.84351916e-03,  1.61462892e-02,
#          3.16869542e-02,  2.18120334e-03,  1.25318542e-02, -4.57241258e-05,
#         -8.76856968e-03,  3.39864902e-02, -1.35461409e-02, -8.79125111e-03,
#          2.87398510e-02, -3.38927656e-03, -1.12696160e-02,  2.31983257e-03,
#         -9.96820163e-03,  1.22182881e-02,  2.48653200e-02,  2.21581245e-03,
#          7.45293312e-03,  1.27884420e-02, -8.32542311e-03, -4.02738893e-04,
#          2.67467331e-02, -1.73375551e-02, -2.40784045e-02,  1.68891009e-02,
#         -1.18706990e-02, -7.66698644e-03,  2.04948261e-02, -7.25837657e-03,
#          1.66657940e-02, -1.84180611e-03,  1.47497663e-02, -8.16353410e-03,
#         -7.14774430e-03, -2.64160857e-02, -1.84907112e-02, -1.92698166e-02,
#         -3.62957120e-02, -3.18337120e-02,  8.03715829e-03, -2.25676931e-02,
#         -1.66086499e-02,  9.15659871e-03, -1.61162857e-02,  2.86314469e-02,
#         -1.67782512e-02, -1.46573177e-02,  3.11027765e-02,  3.98994870e-02,
#          1.33025507e-02,  1.74879804e-02,  1.64161455e-02, -2.92777661e-02,
#          6.93426142e-03,  1.86789352e-02, -1.30266258e-02, -1.58923361e-02,
#          6.17523401e-05, -1.20975198e-02,  3.07307914e-02,  6.06159330e-04,
#         -3.16521935e-02, -3.21645327e-02, -1.09570958e-02, -2.94580054e-03,
#         -2.01286860e-02, -4.42327792e-03, -3.42137995e-03,  1.38091752e-02,
#          1.01592382e-02,  5.40590752e-03,  5.22258924e-05,  1.09248897e-02,
#          1.18354857e-02, -2.11137403e-02,  1.17330393e-02, -2.10113078e-02,
#          1.33739514e-02,  1.86241511e-03, -2.57411152e-02, -9.35692899e-03,
#          2.84899632e-03,  1.34003880e-02,  2.17281263e-02,  1.00900549e-02,
#         -1.38369352e-02, -2.55307928e-02, -2.01793071e-02,  2.29104720e-02,
#         -1.03670610e-02, -1.52047316e-04, -2.00632699e-02,  7.27637962e-05],
#        dtype=float32),
#  array([-9.1464259e-04,  6.6464907e-03, -9.0715848e-04, -7.4972305e-04,
#         -4.3426519e-03, -5.6105051e-03,  9.0000499e-04,  3.4729391e-03,
#         -2.2502095e-03,  7.4194185e-04, -2.0618122e-03, -6.9377869e-03,
#          2.9429495e-03,  1.1873515e-03,  3.6442699e-03, -5.6775035e-03,
#          6.0633868e-03, -6.4259013e-03, -7.6172845e-03, -4.3904269e-03,
#          2.9647062e-03, -4.1615637e-03, -3.9705737e-03,  3.5614818e-03,
#         -1.1211056e-03, -6.1239786e-03, -2.1492941e-03, -7.5099049e-03,
#         -2.1997029e-03, -4.1186530e-04, -1.9729054e-03, -5.6971926e-03,
#         -2.2716746e-03, -5.3634960e-03,  2.4862094e-03,  5.6272857e-03,
#         -6.4859781e-03, -6.8653375e-05,  5.7494007e-03, -4.4523217e-03,
#         -5.8732182e-04,  2.1376265e-03, -6.9410875e-03, -3.3357833e-03,
#         -7.1715880e-03,  3.5522701e-03,  4.6221167e-04, -1.3739476e-03,
#         -3.3991421e-03, -4.5862217e-03,  4.6945047e-03,  1.6517127e-03,
#         -2.0650392e-03, -2.7167080e-03,  1.7221309e-03, -5.5113025e-03,
#         -2.4734177e-03,  3.2183379e-03,  2.2616722e-03, -7.1592564e-03,
#         -1.0922551e-03,  5.7443082e-03,  2.5225468e-03, -5.6864293e-03,
#         -3.4998842e-03, -5.7963682e-03,  5.1403046e-04, -6.7348368e-03,
#         -4.4571199e-03,  3.6389166e-03,  3.7051355e-03,  7.3374789e-03,
#          3.4098448e-03, -5.2137226e-03,  2.5594747e-03, -4.1216752e-03,
#         -6.4680260e-03, -7.2161378e-03,  1.2199776e-03,  6.9319895e-03,
#         -2.2800937e-03,  3.4079012e-03, -6.2692966e-03,  7.5362381e-03,
#         -2.9773209e-03, -1.8535797e-03,  7.2182966e-03, -5.4433001e-03,
#          3.7498791e-03, -7.4990354e-03,  7.7344375e-03, -4.4401875e-03,
#         -4.5608170e-03, -5.8980230e-03, -3.0257469e-03, -3.4715887e-04,
#         -2.3961905e-03, -7.9094898e-04,  5.4151118e-03,  2.3657829e-04,
#          2.7355077e-03, -5.4999143e-03,  5.5790283e-03, -7.4778162e-03,
#         -3.5765367e-03,  1.1560973e-03,  5.3028744e-03,  5.9197145e-03,
#         -2.6242789e-03, -2.2385344e-03,  6.1114766e-03, -7.2409846e-03,
#         -1.8865615e-03, -6.3724127e-03,  2.4604844e-03,  2.4580304e-04,
#         -2.8350567e-03,  2.4297554e-04,  5.2606314e-03,  3.3387681e-03,
#          3.5425657e-03,  7.7196630e-03, -6.2600421e-03, -5.4519130e-03,
#         -6.8279188e-03, -2.4329312e-03, -3.0924808e-03,  3.7472136e-03],
#        dtype=float32),
#  array([ 8.0936076e-03,  2.6906312e-03, -1.1296177e-03, -5.9243767e-03,
#         -1.3796161e-03,  2.7715112e-03,  2.3309156e-04, -3.5253232e-03,
#         -1.2491881e-03,  2.1357203e-03,  8.5098464e-03,  5.3958558e-03,
#          2.4540855e-03, -4.8732986e-03,  8.2371356e-03,  8.9934533e-03,
#          4.0367874e-03,  3.7902796e-03, -8.5334070e-03, -3.5763655e-03,
#          6.4718951e-03, -2.5280016e-03,  2.1322302e-03,  2.0060292e-04,
#         -5.3860196e-03,  7.7774720e-03, -6.9051636e-03,  4.1489890e-03,
#          5.0733597e-03,  4.6680812e-03,  4.3692640e-03, -4.7983653e-03,
#          3.5794510e-03,  2.5948866e-03,  4.0142131e-03, -3.2563137e-03,
#         -3.3132047e-03,  7.3891194e-03,  2.6611306e-03, -2.4094053e-03,
#         -2.9282144e-03,  6.2448983e-03,  5.7776244e-03,  2.1304267e-03,
#         -7.6476345e-04,  1.5597969e-03,  3.2819279e-03,  6.2654633e-04,
#         -5.8951741e-03, -3.5059524e-03, -4.2370244e-04,  7.4988827e-03,
#          1.3222985e-03, -3.1758605e-03, -7.6782466e-03, -1.0532751e-03,
#          3.3025036e-03,  1.3874086e-03, -9.1825528e-03, -1.1065310e-03,
#          4.4876225e-03, -7.1602180e-03,  1.8678498e-03, -1.6411145e-03,
#          8.0557549e-03,  5.1503829e-03, -4.2910309e-05,  1.4408758e-03,
#          2.4138344e-03, -1.3234274e-03, -2.8227440e-03,  4.6194573e-03,
#         -2.2396300e-05, -7.3565720e-03,  5.9866798e-03,  8.4387523e-04,
#          2.6696436e-03, -2.4336101e-03,  4.8170188e-03, -3.6169272e-03,
#         -3.7864062e-03, -5.3127822e-03, -2.3560042e-03,  9.2662722e-03,
#          6.3194740e-03,  3.6564791e-03,  5.3278264e-03,  1.8355722e-03,
#         -4.4944589e-03,  7.2059561e-03, -5.8438438e-03,  6.0296472e-04,
#         -8.6452108e-04,  5.7665184e-03,  6.8048616e-03,  2.7903024e-04,
#          3.0057873e-03,  5.8713704e-03, -7.1842438e-03, -5.7905740e-03,
#         -1.5054661e-03,  3.2370925e-04,  6.2551056e-03, -1.2902524e-03,
#         -3.8562212e-03,  6.3939937e-03, -1.7571439e-03, -2.8193174e-03,
#         -7.2403816e-03, -3.6770196e-03,  7.7334023e-03, -5.7815446e-04,
#          2.8277594e-03, -7.2076330e-03,  4.9389210e-03,  2.4773697e-03,
#          1.7681323e-03, -8.3060266e-04,  6.1188890e-03, -3.9674470e-04,
#          4.6828808e-03,  3.9456487e-03,  4.2520887e-03,  6.0307225e-03,
#          6.4555812e-03,  1.1133134e-03,  1.2309473e-03, -7.8664074e-04],
#        dtype=float32),
#  array([-5.8478769e-04,  3.2076836e-03, -7.4407477e-03, -2.3562349e-03,
#         -5.4194545e-03,  1.3267258e-03, -5.3348802e-03, -3.9711380e-03,
#          7.7234302e-04, -6.7292061e-03,  3.3760602e-03, -7.3555382e-03,
#          3.9083716e-03, -4.2329393e-03,  1.8308461e-03, -1.0438208e-03,
#          1.7392058e-03,  5.8665667e-03, -5.2791685e-03, -3.5871537e-03,
#         -1.6903616e-03, -1.7789882e-03,  5.3565027e-03, -4.2832252e-03,
#         -6.4679487e-03, -7.7744490e-03,  1.4495160e-03,  2.0326693e-03,
#         -5.3116446e-03,  6.9719125e-03,  2.6181461e-03,  2.6719039e-03,
#         -7.6301498e-03, -3.7692720e-03,  1.1401484e-03,  6.1521539e-03,
#          4.3396484e-03, -5.2883569e-04, -2.4584290e-03,  6.6517061e-03,
#          1.2873532e-03,  4.9770623e-04, -2.0806426e-03,  5.7378970e-03,
#         -3.0278638e-03, -5.5423053e-03, -6.2891748e-03, -5.1141530e-04,
#         -3.5765152e-03,  9.6244738e-04,  4.5253141e-03,  5.0572716e-03,
#         -6.1262110e-03,  6.5048607e-03,  3.3945376e-03, -2.4090298e-03,
#          7.0237089e-04, -4.7259573e-03,  6.8739858e-03, -5.3944336e-03,
#          7.0449570e-03,  5.9396299e-03,  4.8832716e-03,  2.9723998e-03,
#          6.8600206e-03,  2.2894833e-03,  2.7970448e-03, -7.2761346e-03,
#          5.9113447e-03, -4.4904500e-03, -2.0792717e-03,  6.6316873e-04,
#          5.8065681e-03, -7.5582229e-03, -6.9432491e-03, -1.1039739e-03,
#          6.2424699e-03,  6.5704975e-03,  4.6454128e-03,  3.7859064e-03,
#         -9.8938122e-04,  1.9320771e-03,  2.0845803e-03, -2.7658818e-03,
#          6.1342269e-03, -7.1019139e-03,  8.5163862e-04, -4.0571224e-03,
#          2.7557202e-03,  7.4964017e-04,  4.2343168e-03,  5.2440269e-03,
#          2.6875734e-04, -2.3728190e-03,  3.6298679e-03, -6.2573804e-03,
#         -3.6793221e-03,  2.6700087e-05, -7.3719826e-03, -6.6328598e-03,
#         -4.5491355e-03, -1.6061170e-03,  4.1094841e-03, -1.6316641e-03,
#         -5.8867270e-03, -2.4560979e-03,  2.7837846e-03,  3.4237588e-03,
#         -3.1608464e-03,  3.9640609e-03,  4.8185112e-03,  5.1048649e-03,
#         -4.9461219e-03, -2.0001503e-03,  4.0760702e-03,  2.6699854e-03,
#         -3.5487395e-03,  4.4537084e-03, -6.4407084e-03,  1.9599283e-03,
#         -5.3110998e-03, -2.8313817e-03,  4.8348717e-03, -1.8812958e-03,
#          6.5547973e-04,  5.5189775e-03, -2.0485809e-03, -3.8858503e-05],
#        dtype=float32),
#  array([ 0.02013267, -0.04540691,  0.04636139,  0.04268385,  0.02939446,
#         -0.0217064 , -0.01235697,  0.03162188, -0.00411634,  0.04944315,
#          0.04404025, -0.00331819, -0.02872485, -0.04812374,  0.04660809,
#          0.06420619, -0.04795314,  0.0334723 , -0.04625332,  0.05217493,
#          0.02809465,  0.01028613, -0.04377236, -0.08374934, -0.07367941,
#          0.01628155, -0.05073754,  0.02878714,  0.00588996,  0.00549554,
#         -0.03796783, -0.00586122,  0.00851155,  0.02829223, -0.01397847,
#          0.04703596,  0.0592864 , -0.00581833,  0.03408492, -0.01162469,
#         -0.0294028 ,  0.08569374, -0.01840195, -0.02357354,  0.06333636,
#          0.00088101, -0.04132931,  0.0137176 , -0.01064257,  0.02478011,
#          0.06004819,  0.00471627,  0.02113851,  0.02740179, -0.01503569,
#         -0.00527127,  0.0448372 , -0.02765637, -0.0497195 ,  0.02839809,
#         -0.03808432, -0.00814372,  0.02911707, -0.03068538,  0.04459459,
#         -0.00325214,  0.02389421, -0.0109976 , -0.00636414, -0.04692644,
#         -0.03956771, -0.04147769, -0.08645882, -0.06768967,  0.01949006,
#         -0.05253404, -0.04256689,  0.01966726, -0.02389576,  0.07662509,
#         -0.03851869, -0.04184688,  0.06475805,  0.10446654,  0.0417515 ,
#          0.02747609,  0.04354185, -0.07572355,  0.02537322,  0.02817455,
#         -0.01783027, -0.03882149, -0.00028927, -0.01538333,  0.0742695 ,
#          0.00231543, -0.06047825, -0.06806307, -0.00862379, -0.01177532,
#         -0.0615989 , -0.00508086, -0.0052502 ,  0.02436187,  0.00514314,
#          0.02177753,  0.01148326,  0.0259533 ,  0.00985135, -0.04900016,
#          0.04188233, -0.04538558,  0.01159165,  0.01535941, -0.04854137,
#         -0.03325992,  0.02037796,  0.02351591,  0.04634098,  0.00889625,
#         -0.04374738, -0.05037678, -0.03633886,  0.03385944, -0.02422938,
#         -0.0119153 , -0.0286225 , -0.01836128], dtype=float32),
#  array([ 0.00590512, -0.02011385,  0.01910295,  0.01415231,  0.01850622,
#         -0.00935043, -0.00596259,  0.01340286, -0.00577854,  0.02147788,
#          0.02037383, -0.00447623, -0.01180076, -0.02476268,  0.02591468,
#          0.03007096, -0.0183166 ,  0.01361732, -0.01608768,  0.0233209 ,
#          0.01232356,  0.00774209, -0.0194941 , -0.03519899, -0.03156245,
#          0.00960012, -0.0187577 ,  0.0110363 ,  0.00608933,  0.00550206,
#         -0.01401658, -0.00156209,  0.00421921,  0.01135707, -0.01262173,
#          0.02313657,  0.02737153, -0.00242672,  0.01451424, -0.00948099,
#         -0.00808507,  0.03624741, -0.00705636, -0.00908228,  0.03180674,
#          0.00271072, -0.01994896,  0.00775728, -0.00562888,  0.00987675,
#          0.02632131,  0.00642111,  0.01141513,  0.01376   , -0.00960399,
#         -0.00049801,  0.02121245, -0.0067427 , -0.0175821 ,  0.00999014,
#         -0.02011841, -0.00393899,  0.0144008 , -0.01948897,  0.02051818,
#         -0.00331071,  0.01203492, -0.00587811, -0.00194031, -0.02083449,
#         -0.01923275, -0.02145996, -0.03799475, -0.02888069,  0.00647354,
#         -0.02057667, -0.01913477,  0.01519769, -0.0129976 ,  0.03767563,
#         -0.0194653 , -0.01974761,  0.02348657,  0.04306051,  0.02486098,
#          0.0099121 ,  0.01733504, -0.03571479,  0.00734425,  0.01043845,
#         -0.01011431, -0.0162417 , -0.00161529, -0.00882718,  0.03224787,
#          0.00372665, -0.02792812, -0.02688537, -0.00290148, -0.00593195,
#         -0.0274734 , -0.00307551, -0.00229849,  0.0140772 ,  0.005261  ,
#          0.01282892,  0.00450709,  0.01179906,  0.00074318, -0.01965208,
#          0.01757421, -0.01766362,  0.00427447,  0.007771  , -0.02241306,
#         -0.02090319,  0.00418021,  0.00593833,  0.02436278,  0.0069519 ,
#         -0.02419234, -0.02054361, -0.01612308,  0.0135622 , -0.01327676,
#         -0.00730181, -0.01595688, -0.0053979 ], dtype=float32),
#  array([ 9.42969602e-03, -1.19439624e-02,  1.48304384e-02,  1.42709650e-02,
#          5.10896649e-03, -5.22695761e-03, -3.77514225e-05,  1.22871995e-03,
#          7.15945894e-03,  3.19339894e-03,  3.02918954e-03,  1.03010645e-03,
#         -9.38105455e-04, -1.36747705e-02,  1.17415823e-02,  2.04545707e-02,
#         -1.47647914e-02,  1.64676830e-03, -1.32296328e-02,  8.32361635e-03,
#          6.98685925e-03,  9.53387842e-03, -4.43536462e-03, -1.75772179e-02,
#         -1.34487543e-02,  1.00997509e-02, -3.37762432e-03,  1.04563329e-02,
#          6.19692868e-03, -5.34859160e-03, -1.09900562e-02, -5.46655245e-03,
#          5.98693080e-03,  3.67922196e-03, -9.89204366e-03,  1.57802738e-02,
#          1.93882789e-02, -4.09608847e-03,  1.41899278e-02, -2.94416700e-03,
#         -8.72108154e-03,  1.72688477e-02, -3.51782027e-03, -7.63557432e-03,
#          1.58426035e-02,  5.22042997e-03, -3.15360702e-03, -4.22055833e-03,
#         -4.02431702e-03,  1.26459741e-03,  1.79705303e-02,  6.01415802e-03,
#          1.34999782e-03,  7.83223193e-03, -8.01484659e-03, -5.75621147e-04,
#          1.65769421e-02, -7.09300069e-03, -1.45615283e-02,  2.58827698e-04,
#         -1.05915898e-02, -2.42378423e-03,  8.50096159e-03,  1.41210249e-03,
#          6.49627810e-03,  7.67567311e-04,  1.25230728e-02, -1.44324207e-03,
#         -8.65801354e-04, -1.46213558e-03, -9.63685685e-04, -2.79214373e-03,
#         -2.29102820e-02, -5.42768743e-03,  8.61262530e-03, -3.92649090e-03,
#         -1.06081869e-02,  6.78084139e-03,  6.71187590e-05,  1.31860599e-02,
#         -2.40283646e-03, -7.11876480e-03,  2.08804514e-02,  1.86920613e-02,
#          6.75026840e-03,  1.03737963e-02,  1.32125127e-03, -2.10877787e-02,
#          7.30402535e-05,  4.88562742e-03, -5.68448566e-03, -3.24407709e-03,
#          7.61769200e-03, -3.67536093e-03,  1.59850772e-02,  2.02194648e-03,
#         -1.39789796e-02, -2.04276722e-02,  3.76635441e-03, -5.69170760e-03,
#         -8.75409134e-03,  5.85080311e-03,  1.38557039e-03,  7.48091005e-03,
#          4.28607827e-03,  2.33971397e-03,  5.05615165e-03,  6.54757349e-03,
#          6.53455267e-03, -5.57036279e-03,  9.14369710e-03, -4.55318717e-03,
#         -4.36464045e-03,  8.56014900e-03, -2.36343569e-03, -1.05272550e-02,
#          6.00578263e-03,  8.18115077e-04,  1.03766844e-02,  4.55409568e-03,
#         -3.02283047e-03, -9.80125647e-03, -5.58270374e-03,  8.02579429e-03,
#          1.17566751e-03, -6.78309985e-03, -1.01967268e-02, -6.24344265e-03],
#        dtype=float32),
#  array([ 1.53585561e-02, -2.48949919e-02,  2.73398869e-02,  1.28576765e-02,
#          1.77861825e-02, -6.45618711e-04, -1.22217005e-02,  6.83573494e-03,
#         -4.79353173e-03,  2.12111920e-02,  1.86758023e-02, -9.59818438e-03,
#         -1.98295135e-02, -1.97147857e-02,  1.46305505e-02,  2.28987690e-02,
#         -2.30956692e-02,  7.10436935e-03, -2.61121690e-02,  1.77317578e-02,
#          1.21788038e-02,  9.69405519e-04, -1.53783970e-02, -3.81949916e-02,
#         -3.69610488e-02,  1.24777090e-02, -2.79252864e-02,  9.09584016e-03,
#         -2.71199318e-03, -1.70203648e-03, -1.88789312e-02,  2.78673624e-03,
#          6.89103850e-04,  1.64989140e-02, -1.84351916e-03,  1.61462892e-02,
#          3.16869542e-02,  2.18120334e-03,  1.25318542e-02, -4.57241258e-05,
#         -8.76856968e-03,  3.39864902e-02, -1.35461409e-02, -8.79125111e-03,
#          2.87398510e-02, -3.38927656e-03, -1.12696160e-02,  2.31983257e-03,
#         -9.96820163e-03,  1.22182881e-02,  2.48653200e-02,  2.21581245e-03,
#          7.45293312e-03,  1.27884420e-02, -8.32542311e-03, -4.02738893e-04,
#          2.67467331e-02, -1.73375551e-02, -2.40784045e-02,  1.68891009e-02,
#         -1.18706990e-02, -7.66698644e-03,  2.04948261e-02, -7.25837657e-03,
#          1.66657940e-02, -1.84180611e-03,  1.47497663e-02, -8.16353410e-03,
#         -7.14774430e-03, -2.64160857e-02, -1.84907112e-02, -1.92698166e-02,
#         -3.62957120e-02, -3.18337120e-02,  8.03715829e-03, -2.25676931e-02,
#         -1.66086499e-02,  9.15659871e-03, -1.61162857e-02,  2.86314469e-02,
#         -1.67782512e-02, -1.46573177e-02,  3.11027765e-02,  3.98994870e-02,
#          1.33025507e-02,  1.74879804e-02,  1.64161455e-02, -2.92777661e-02,
#          6.93426142e-03,  1.86789352e-02, -1.30266258e-02, -1.58923361e-02,
#          6.17523401e-05, -1.20975198e-02,  3.07307914e-02,  6.06159330e-04,
#         -3.16521935e-02, -3.21645327e-02, -1.09570958e-02, -2.94580054e-03,
#         -2.01286860e-02, -4.42327792e-03, -3.42137995e-03,  1.38091752e-02,
#          1.01592382e-02,  5.40590752e-03,  5.22258924e-05,  1.09248897e-02,
#          1.18354857e-02, -2.11137403e-02,  1.17330393e-02, -2.10113078e-02,
#          1.33739514e-02,  1.86241511e-03, -2.57411152e-02, -9.35692899e-03,
#          2.84899632e-03,  1.34003880e-02,  2.17281263e-02,  1.00900549e-02,
#         -1.38369352e-02, -2.55307928e-02, -2.01793071e-02,  2.29104720e-02,
#         -1.03670610e-02, -1.52047316e-04, -2.00632699e-02,  7.27637962e-05],
#        dtype=float32),
#  array([ 1.53585561e-02, -2.48949919e-02,  2.73398869e-02,  1.28576765e-02,
#          1.77861825e-02, -6.45618711e-04, -1.22217005e-02,  6.83573494e-03,
#         -4.79353173e-03,  2.12111920e-02,  1.86758023e-02, -9.59818438e-03,
#         -1.98295135e-02, -1.97147857e-02,  1.46305505e-02,  2.28987690e-02,
#         -2.30956692e-02,  7.10436935e-03, -2.61121690e-02,  1.77317578e-02,
#          1.21788038e-02,  9.69405519e-04, -1.53783970e-02, -3.81949916e-02,
#         -3.69610488e-02,  1.24777090e-02, -2.79252864e-02,  9.09584016e-03,
#         -2.71199318e-03, -1.70203648e-03, -1.88789312e-02,  2.78673624e-03,
#          6.89103850e-04,  1.64989140e-02, -1.84351916e-03,  1.61462892e-02,
#          3.16869542e-02,  2.18120334e-03,  1.25318542e-02, -4.57241258e-05,
#         -8.76856968e-03,  3.39864902e-02, -1.35461409e-02, -8.79125111e-03,
#          2.87398510e-02, -3.38927656e-03, -1.12696160e-02,  2.31983257e-03,
#         -9.96820163e-03,  1.22182881e-02,  2.48653200e-02,  2.21581245e-03,
#          7.45293312e-03,  1.27884420e-02, -8.32542311e-03, -4.02738893e-04,
#          2.67467331e-02, -1.73375551e-02, -2.40784045e-02,  1.68891009e-02,
#         -1.18706990e-02, -7.66698644e-03,  2.04948261e-02, -7.25837657e-03,
#          1.66657940e-02, -1.84180611e-03,  1.47497663e-02, -8.16353410e-03,
#         -7.14774430e-03, -2.64160857e-02, -1.84907112e-02, -1.92698166e-02,
#         -3.62957120e-02, -3.18337120e-02,  8.03715829e-03, -2.25676931e-02,
#         -1.66086499e-02,  9.15659871e-03, -1.61162857e-02,  2.86314469e-02,
#         -1.67782512e-02, -1.46573177e-02,  3.11027765e-02,  3.98994870e-02,
#          1.33025507e-02,  1.74879804e-02,  1.64161455e-02, -2.92777661e-02,
#          6.93426142e-03,  1.86789352e-02, -1.30266258e-02, -1.58923361e-02,
#          6.17523401e-05, -1.20975198e-02,  3.07307914e-02,  6.06159330e-04,
#         -3.16521935e-02, -3.21645327e-02, -1.09570958e-02, -2.94580054e-03,
#         -2.01286860e-02, -4.42327792e-03, -3.42137995e-03,  1.38091752e-02,
#          1.01592382e-02,  5.40590752e-03,  5.22258924e-05,  1.09248897e-02,
#          1.18354857e-02, -2.11137403e-02,  1.17330393e-02, -2.10113078e-02,
#          1.33739514e-02,  1.86241511e-03, -2.57411152e-02, -9.35692899e-03,
#          2.84899632e-03,  1.34003880e-02,  2.17281263e-02,  1.00900549e-02,
#         -1.38369352e-02, -2.55307928e-02, -2.01793071e-02,  2.29104720e-02,
#         -1.03670610e-02, -1.52047316e-04, -2.00632699e-02,  7.27637962e-05],
#        dtype=float32),
#  array([ 1.53585561e-02, -2.48949919e-02,  2.73398869e-02,  1.28576765e-02,
#          1.77861825e-02, -6.45618711e-04, -1.22217005e-02,  6.83573494e-03,
#         -4.79353173e-03,  2.12111920e-02,  1.86758023e-02, -9.59818438e-03,
#         -1.98295135e-02, -1.97147857e-02,  1.46305505e-02,  2.28987690e-02,
#         -2.30956692e-02,  7.10436935e-03, -2.61121690e-02,  1.77317578e-02,
#          1.21788038e-02,  9.69405519e-04, -1.53783970e-02, -3.81949916e-02,
#         -3.69610488e-02,  1.24777090e-02, -2.79252864e-02,  9.09584016e-03,
#         -2.71199318e-03, -1.70203648e-03, -1.88789312e-02,  2.78673624e-03,
#          6.89103850e-04,  1.64989140e-02, -1.84351916e-03,  1.61462892e-02,
#          3.16869542e-02,  2.18120334e-03,  1.25318542e-02, -4.57241258e-05,
#         -8.76856968e-03,  3.39864902e-02, -1.35461409e-02, -8.79125111e-03,
#          2.87398510e-02, -3.38927656e-03, -1.12696160e-02,  2.31983257e-03,
#         -9.96820163e-03,  1.22182881e-02,  2.48653200e-02,  2.21581245e-03,
#          7.45293312e-03,  1.27884420e-02, -8.32542311e-03, -4.02738893e-04,
#          2.67467331e-02, -1.73375551e-02, -2.40784045e-02,  1.68891009e-02,
#         -1.18706990e-02, -7.66698644e-03,  2.04948261e-02, -7.25837657e-03,
#          1.66657940e-02, -1.84180611e-03,  1.47497663e-02, -8.16353410e-03,
#         -7.14774430e-03, -2.64160857e-02, -1.84907112e-02, -1.92698166e-02,
#         -3.62957120e-02, -3.18337120e-02,  8.03715829e-03, -2.25676931e-02,
#         -1.66086499e-02,  9.15659871e-03, -1.61162857e-02,  2.86314469e-02,
#         -1.67782512e-02, -1.46573177e-02,  3.11027765e-02,  3.98994870e-02,
#          1.33025507e-02,  1.74879804e-02,  1.64161455e-02, -2.92777661e-02,
#          6.93426142e-03,  1.86789352e-02, -1.30266258e-02, -1.58923361e-02,
#          6.17523401e-05, -1.20975198e-02,  3.07307914e-02,  6.06159330e-04,
#         -3.16521935e-02, -3.21645327e-02, -1.09570958e-02, -2.94580054e-03,
#         -2.01286860e-02, -4.42327792e-03, -3.42137995e-03,  1.38091752e-02,
#          1.01592382e-02,  5.40590752e-03,  5.22258924e-05,  1.09248897e-02,
#          1.18354857e-02, -2.11137403e-02,  1.17330393e-02, -2.10113078e-02,
#          1.33739514e-02,  1.86241511e-03, -2.57411152e-02, -9.35692899e-03,
#          2.84899632e-03,  1.34003880e-02,  2.17281263e-02,  1.00900549e-02,
#         -1.38369352e-02, -2.55307928e-02, -2.01793071e-02,  2.29104720e-02,
#         -1.03670610e-02, -1.52047316e-04, -2.00632699e-02,  7.27637962e-05],
#        dtype=float32),
#  array([-1.0634378e-03, -5.1744905e-04,  1.4604320e-03,  2.3736360e-03,
#          4.8327600e-03, -1.8489272e-03, -1.9336478e-03,  5.2142753e-03,
#          2.1313038e-03,  3.6108189e-03,  2.1971932e-03, -1.4187185e-03,
#          1.4957354e-03, -1.8186662e-03,  2.3124497e-03,  4.0663476e-03,
#         -1.2378040e-03,  2.2442283e-03, -4.2937598e-03, -1.8347722e-03,
#          9.1514690e-04, -2.5287373e-03, -1.4938582e-03, -7.1206358e-03,
#         -6.1614364e-03,  9.7180839e-04,  4.1701877e-04,  5.4894630e-03,
#          4.4304742e-03,  1.9588151e-03,  1.0027338e-03, -5.6261796e-04,
#          1.5294707e-03,  1.7061229e-03, -1.0950421e-03, -7.0322509e-04,
#          2.4039503e-03, -5.4440033e-03,  1.7220159e-04,  3.4219408e-04,
#          1.0681938e-03,  4.9790177e-03, -7.4953400e-04, -3.3778076e-03,
#          3.7075239e-04, -4.5675356e-03, -4.9062776e-03,  2.3531532e-03,
#         -1.8516557e-03,  2.8886905e-04, -3.3845569e-03,  3.2078553e-04,
#          1.7777701e-03,  3.3870663e-03, -1.7299167e-03,  7.3208456e-04,
#          1.7602699e-03,  1.8059798e-03, -6.4012110e-03,  1.9968359e-03,
#         -2.5382407e-03,  7.6138013e-04,  3.3405095e-03, -4.5537562e-03,
#         -1.6350411e-03,  3.4181457e-03,  1.0124879e-03,  1.0177767e-03,
#          2.0511413e-03, -2.0734996e-04, -2.0870618e-03, -3.4132337e-03,
#         -4.5205192e-03, -3.3764269e-03,  1.5726936e-03, -4.4207727e-03,
#         -7.2665676e-03, -7.4236328e-04,  3.4854438e-05,  6.3704457e-03,
#         -1.5790235e-03, -2.0740104e-03,  6.3119978e-03,  3.3271406e-03,
#          1.1714831e-03, -2.3251441e-03, -6.6734338e-04, -5.4245442e-03,
#         -3.2003953e-03,  6.5203221e-03,  4.5463741e-03, -5.6028008e-03,
#          1.8071253e-03,  7.3060399e-04,  1.0503904e-03, -2.9429724e-04,
#         -6.6631772e-03, -2.2095744e-03,  3.8650376e-04,  1.2546402e-03,
#         -7.1621995e-04, -4.2732756e-04, -2.3596615e-03, -1.6851631e-03,
#          1.6207454e-03,  6.1298055e-03, -3.4610101e-03,  5.9645302e-03,
#          3.1742435e-03, -2.7302445e-03,  5.7254749e-04, -1.2473393e-03,
#         -5.0434116e-03,  1.1801628e-03, -9.9220313e-05, -7.6865014e-03,
#          2.1826101e-03, -2.3117331e-03,  2.3414770e-03, -2.9045036e-03,
#         -3.9876462e-03, -5.2427314e-04, -2.0856836e-03,  5.9293695e-03,
#         -2.5211673e-03,  1.4848360e-03, -2.4439634e-03, -2.1943466e-04],
#        dtype=float32),
#  array([ 0.02151151, -0.04070671,  0.04461131,  0.04072509,  0.02994852,
#         -0.0195657 , -0.01262572,  0.03334411, -0.00317681,  0.05088183,
#          0.04013382, -0.00490495, -0.02984845, -0.0446295 ,  0.04282657,
#          0.06296229, -0.04505479,  0.02876683, -0.04610117,  0.05054284,
#          0.02736812,  0.01079683, -0.04153567, -0.08369794, -0.07230455,
#          0.01481571, -0.04987865,  0.02923348,  0.00631056,  0.00294071,
#         -0.03809049, -0.00461913,  0.0066864 ,  0.02585392, -0.01539358,
#          0.0457361 ,  0.06160948, -0.00713004,  0.03227523, -0.01158762,
#         -0.03040695,  0.08216012, -0.01868879, -0.02494739,  0.06288534,
# ...
#          2.87398510e-02, -3.38927656e-03, -1.12696160e-02,  2.31983257e-03,
#         -9.96820163e-03,  1.22182881e-02,  2.48653200e-02,  2.21581245e-03,
#          7.45293312e-03,  1.27884420e-02, -8.32542311e-03, -4.02738893e-04,
#          2.67467331e-02, -1.73375551e-02, -2.40784045e-02,  1.68891009e-02,
#         -1.18706990e-02, -7.66698644e-03,  2.04948261e-02, -7.25837657e-03,
#          1.66657940e-02, -1.84180611e-03,  1.47497663e-02, -8.16353410e-03,
#         -7.14774430e-03, -2.64160857e-02, -1.84907112e-02, -1.92698166e-02,
#         -3.62957120e-02, -3.18337120e-02,  8.03715829e-03, -2.25676931e-02,
#         -1.66086499e-02,  9.15659871e-03, -1.61162857e-02,  2.86314469e-02,
#         -1.67782512e-02, -1.46573177e-02,  3.11027765e-02,  3.98994870e-02,
#          1.33025507e-02,  1.74879804e-02,  1.64161455e-02, -2.92777661e-02,
#          6.93426142e-03,  1.86789352e-02, -1.30266258e-02, -1.58923361e-02,
#          6.17523401e-05, -1.20975198e-02,  3.07307914e-02,  6.06159330e-04,
#         -3.16521935e-02, -3.21645327e-02, -1.09570958e-02, -2.94580054e-03,
#         -2.01286860e-02, -4.42327792e-03, -3.42137995e-03,  1.38091752e-02,
#          1.01592382e-02,  5.40590752e-03,  5.22258924e-05,  1.09248897e-02,
#          1.18354857e-02, -2.11137403e-02,  1.17330393e-02, -2.10113078e-02,
#          1.33739514e-02,  1.86241511e-03, -2.57411152e-02, -9.35692899e-03,
#          2.84899632e-03,  1.34003880e-02,  2.17281263e-02,  1.00900549e-02,
#         -1.38369352e-02, -2.55307928e-02, -2.01793071e-02,  2.29104720e-02,
#         -1.03670610e-02, -1.52047316e-04, -2.00632699e-02,  7.27637962e-05],
#        dtype=float32),
#  array([ 1.53585561e-02, -2.48949919e-02,  2.73398869e-02,  1.28576765e-02,
#          1.77861825e-02, -6.45618711e-04, -1.22217005e-02,  6.83573494e-03,
#         -4.79353173e-03,  2.12111920e-02,  1.86758023e-02, -9.59818438e-03,
#         -1.98295135e-02, -1.97147857e-02,  1.46305505e-02,  2.28987690e-02,
#         -2.30956692e-02,  7.10436935e-03, -2.61121690e-02,  1.77317578e-02,
#          1.21788038e-02,  9.69405519e-04, -1.53783970e-02, -3.81949916e-02,
#         -3.69610488e-02,  1.24777090e-02, -2.79252864e-02,  9.09584016e-03,
#         -2.71199318e-03, -1.70203648e-03, -1.88789312e-02,  2.78673624e-03,
#          6.89103850e-04,  1.64989140e-02, -1.84351916e-03,  1.61462892e-02,
#          3.16869542e-02,  2.18120334e-03,  1.25318542e-02, -4.57241258e-05,
#         -8.76856968e-03,  3.39864902e-02, -1.35461409e-02, -8.79125111e-03,
#          2.87398510e-02, -3.38927656e-03, -1.12696160e-02,  2.31983257e-03,
#         -9.96820163e-03,  1.22182881e-02,  2.48653200e-02,  2.21581245e-03,
#          7.45293312e-03,  1.27884420e-02, -8.32542311e-03, -4.02738893e-04,
#          2.67467331e-02, -1.73375551e-02, -2.40784045e-02,  1.68891009e-02,
#         -1.18706990e-02, -7.66698644e-03,  2.04948261e-02, -7.25837657e-03,
#          1.66657940e-02, -1.84180611e-03,  1.47497663e-02, -8.16353410e-03,
#         -7.14774430e-03, -2.64160857e-02, -1.84907112e-02, -1.92698166e-02,
#         -3.62957120e-02, -3.18337120e-02,  8.03715829e-03, -2.25676931e-02,
#         -1.66086499e-02,  9.15659871e-03, -1.61162857e-02,  2.86314469e-02,
#         -1.67782512e-02, -1.46573177e-02,  3.11027765e-02,  3.98994870e-02,
#          1.33025507e-02,  1.74879804e-02,  1.64161455e-02, -2.92777661e-02,
#          6.93426142e-03,  1.86789352e-02, -1.30266258e-02, -1.58923361e-02,
#          6.17523401e-05, -1.20975198e-02,  3.07307914e-02,  6.06159330e-04,
#         -3.16521935e-02, -3.21645327e-02, -1.09570958e-02, -2.94580054e-03,
#         -2.01286860e-02, -4.42327792e-03, -3.42137995e-03,  1.38091752e-02,
#          1.01592382e-02,  5.40590752e-03,  5.22258924e-05,  1.09248897e-02,
#          1.18354857e-02, -2.11137403e-02,  1.17330393e-02, -2.10113078e-02,
#          1.33739514e-02,  1.86241511e-03, -2.57411152e-02, -9.35692899e-03,
#          2.84899632e-03,  1.34003880e-02,  2.17281263e-02,  1.00900549e-02,
#         -1.38369352e-02, -2.55307928e-02, -2.01793071e-02,  2.29104720e-02,
#         -1.03670610e-02, -1.52047316e-04, -2.00632699e-02,  7.27637962e-05],
#        dtype=float32),
#  array([ 0.01592703, -0.02233044,  0.02744641,  0.02432435,  0.0098401 ,
#         -0.00430107, -0.01281795,  0.02180421, -0.00359898,  0.01668291,
#          0.01355938,  0.00482058, -0.01422936, -0.02390716,  0.01976672,
#          0.0367451 , -0.02891631,  0.02222105, -0.02411536,  0.02426792,
#          0.01755252,  0.00456054, -0.02020721, -0.04095619, -0.0271558 ,
#          0.01573964, -0.02227208,  0.01324105,  0.01017907,  0.00446325,
#         -0.02233905, -0.00317862,  0.00094694,  0.01668599, -0.00580877,
#          0.02536852,  0.02316637,  0.0008284 ,  0.01503038, -0.00415564,
#         -0.00899799,  0.03959052, -0.01167867, -0.01438418,  0.02637367,
#          0.00187183, -0.01189437,  0.0074382 , -0.00916848,  0.01452239,
#          0.02711336, -0.0049566 ,  0.00292145,  0.00716769, -0.01068077,
#          0.00220416,  0.02343183, -0.00949773, -0.02500333,  0.00696756,
#         -0.01881877,  0.00012225,  0.0200221 , -0.00729495,  0.01689765,
#          0.00521187,  0.01258918, -0.00471481,  0.00087367, -0.02679555,
#         -0.02000474, -0.01496387, -0.03696009, -0.0302625 ,  0.01233471,
#         -0.01838429, -0.01576625,  0.01007162, -0.00447801,  0.03221512,
#         -0.01546576, -0.02611907,  0.03627533,  0.04040366,  0.01365272,
#          0.01892804,  0.01282504, -0.02865119,  0.00944153,  0.0055347 ,
#         -0.01035043, -0.01628328,  0.00805021, -0.01057649,  0.03636532,
#          0.00732045, -0.02932942, -0.0244415 , -0.00918748, -0.00601712,
#         -0.03185023, -0.00444745, -0.00085446,  0.01774482,  0.00895533,
#          0.00683755,  0.00427156,  0.02015113,  0.01183081, -0.0147733 ,
#          0.01397389, -0.02444578,  0.00919026,  0.00668698, -0.02333057,
#         -0.01311199,  0.01111139,  0.00663544,  0.02905893,  0.00797716,
#         -0.02341157, -0.02451964, -0.01761712,  0.0237532 , -0.01007189,
#          0.00065612, -0.01209786, -0.0005409 ], dtype=float32),
#  array([ 0.00135161, -0.00272373,  0.00457514,  0.00197557, -0.00080512,
#         -0.00129356, -0.00590315,  0.00495974,  0.00061332,  0.00500907,
#         -0.00035973, -0.00421403, -0.00227189, -0.00760435,  0.00582975,
#          0.00721736, -0.00647154,  0.00522504, -0.00484539,  0.00102967,
#         -0.00194842,  0.00226163, -0.00230968, -0.00860002, -0.00419383,
#         -0.00514169, -0.00195261,  0.00549901, -0.00349095, -0.00424666,
#         -0.00612501,  0.00641859,  0.00658207,  0.00016514,  0.00157081,
#          0.00379297,  0.00645876, -0.0008483 , -0.0014574 , -0.00099188,
#         -0.00196785,  0.01061046,  0.0012064 , -0.00409144,  0.00834095,
#         -0.00177639,  0.00211061, -0.0046386 , -0.00531979,  0.00568704,
#          0.0050309 , -0.00100775,  0.00137843, -0.00270021,  0.00035006,
#         -0.00026955,  0.00901288, -0.00102521, -0.00061956,  0.00202789,
#         -0.00278722,  0.00522865, -0.00303877, -0.00441374,  0.0070499 ,
#         -0.00417793,  0.00379034,  0.00086008,  0.00370991, -0.00027072,
#          0.00087353,  0.00413467, -0.0066903 , -0.00266407,  0.00203916,
#         -0.00795199, -0.00611267,  0.00477736,  0.00037184,  0.00780407,
#         -0.00617599, -0.00179767,  0.00386139,  0.00781794,  0.00253423,
#         -0.00227791,  0.00641781, -0.01145921, -0.00224175,  0.00044543,
#         -0.00209583, -0.00296489, -0.00442565, -0.00428082,  0.00810333,
#          0.0034104 ,  0.00144968,  0.0019864 ,  0.00271101, -0.00037944,
#         -0.00419218,  0.00104799, -0.00477284, -0.00334027,  0.00694229,
#          0.0072029 , -0.00627007,  0.00217662, -0.00522986, -0.00011731,
#          0.00710899, -0.00368724,  0.00022455,  0.00279628, -0.00264975,
#         -0.00133449,  0.00488668,  0.00013791,  0.00044054, -0.00141237,
#         -0.00955526,  0.00224769, -0.00722199,  0.00560528, -0.00279863,
#          0.00463035, -0.00670294, -0.00051569], dtype=float32),
#  array([ 0.01448434, -0.01793562,  0.0212299 ,  0.01741502,  0.01279379,
#         -0.00593176, -0.00908366,  0.01075739,  0.00071233,  0.01964892,
#          0.01482079, -0.00062022, -0.01477627, -0.01903579,  0.02008985,
#          0.02830314, -0.01840415,  0.01387395, -0.02052161,  0.02232648,
#          0.01378265,  0.00575196, -0.01495297, -0.03670693, -0.03492534,
#          0.00304644, -0.01985458,  0.00865437,  0.00485096, -0.00474616,
#         -0.01165429, -0.00028023,  0.00374257,  0.0098946 , -0.00544254,
#          0.01924255,  0.02738636, -0.00422127,  0.01419748, -0.00378228,
#         -0.01406509,  0.03886362, -0.0110945 , -0.00991816,  0.02497174,
#          0.00115019, -0.01372527,  0.00557174, -0.00231615,  0.01435003,
#          0.02543494,  0.00193787,  0.00741818,  0.01062036, -0.01196043,
#          0.00254721,  0.01885868, -0.00897289, -0.01967688,  0.01171265,
#         -0.01809538, -0.00107187,  0.00916992, -0.00986601,  0.02175774,
#         -0.00168124,  0.0111346 , -0.0055987 , -0.00054723, -0.01650752,
#         -0.01345843, -0.01412811, -0.03403925, -0.02779367,  0.00450889,
#         -0.02384456, -0.01840627,  0.00857157, -0.00905157,  0.03774033,
#         -0.01597488, -0.0200014 ,  0.02396326,  0.04489611,  0.01657135,
#          0.0109586 ,  0.01829387, -0.03060103,  0.01107568,  0.00943368,
#         -0.00524266, -0.01515693,  0.00326377, -0.00997548,  0.02660336,
#          0.00110129, -0.02326573, -0.02302467, -0.00407782, -0.00537664,
#         -0.02342587,  0.00077805, -0.00208703,  0.01234744,  0.00413941,
#          0.00868142,  0.00688121,  0.01612551,  0.00434446, -0.01797212,
#          0.01667335, -0.01702255,  0.00849451,  0.00716171, -0.02113921,
#         -0.01911996,  0.00936934,  0.00939966,  0.01917594,  0.00359152,
#         -0.01961213, -0.02096184, -0.0171686 ,  0.01190367, -0.01181628,
#         -0.00220479, -0.01601122, -0.00927239], dtype=float32),
#  array([ 0.01545759, -0.03123907,  0.03684756,  0.02699711,  0.02463627,
#         -0.01561523, -0.01110556,  0.02514674, -0.00447351,  0.03634169,
#          0.02926258, -0.00334345, -0.02027263, -0.0351574 ,  0.03231835,
#          0.04819942, -0.03449671,  0.02122206, -0.03224557,  0.0400552 ,
#          0.02072538,  0.0052341 , -0.03148372, -0.06426484, -0.0540239 ,
#          0.01286643, -0.03589151,  0.02012823,  0.0058294 ,  0.00210357,
#         -0.02932094, -0.00197962,  0.00503984,  0.01747086, -0.00974771,
#          0.03869972,  0.04381121, -0.00150206,  0.02385425, -0.00973173,
#         -0.02017317,  0.06295226, -0.01387116, -0.0185504 ,  0.0496996 ,
#          0.00102607, -0.03006676,  0.00916533, -0.00776698,  0.01975318,
#          0.0433821 ,  0.00641264,  0.01280864,  0.02259255, -0.01217626,
#         -0.00072084,  0.03194889, -0.01919061, -0.03477042,  0.02035258,
#         -0.02960604, -0.00640686,  0.02160252, -0.02381017,  0.02995829,
#         -0.00286353,  0.01773526, -0.00983783, -0.00270142, -0.03640583,
#         -0.03247733, -0.02920065, -0.06214332, -0.04667094,  0.01238313,
#         -0.04124096, -0.03312568,  0.01611057, -0.01956584,  0.05825512,
#         -0.03059714, -0.0312987 ,  0.04632702,  0.07316587,  0.03462915,
#          0.02059585,  0.03387653, -0.05292552,  0.01975706,  0.01811384,
#         -0.01435845, -0.02806214,  0.00053753, -0.01038023,  0.05128336,
#          0.00068981, -0.04212186, -0.04743871, -0.00670277, -0.00685569,
#         -0.04357531, -0.00074901, -0.00280916,  0.0144877 ,  0.00590268,
#          0.013781  ,  0.00827379,  0.0167002 ,  0.00430406, -0.0355535 ,
#          0.02902554, -0.03181647,  0.00810332,  0.00969183, -0.03495403,
#         -0.02344169,  0.01468546,  0.01459792,  0.03203439,  0.01112781,
#         -0.03266453, -0.03535739, -0.02701721,  0.02326238, -0.01969704,
#         -0.00620265, -0.01999932, -0.01188116], dtype=float32),
#  array([ 5.07919164e-03, -7.54371192e-03,  5.38265565e-03,  6.68509398e-03,
#          6.02785964e-03,  3.44414584e-04, -4.07353183e-03,  5.46069536e-03,
#         -8.02953786e-04,  9.03971493e-03,  6.27476815e-03,  7.34840141e-05,
#         -5.95449284e-03, -7.18373433e-03,  3.40780173e-03,  9.95199662e-03,
#         -6.38260273e-03,  3.21911671e-03, -8.18372145e-03,  9.24857799e-03,
#          3.72515200e-03,  7.40158895e-04, -6.30211737e-03, -1.40703777e-02,
#         -1.09715415e-02,  1.27160945e-03, -1.03528695e-02,  4.25493252e-03,
#          6.16790378e-04,  5.76416031e-04, -7.74615537e-03,  1.00771767e-05,
#         -3.68502992e-03,  4.58836509e-03, -1.11689523e-03,  6.23425515e-03,
#          8.30724556e-03, -2.56113592e-03,  2.73754937e-03, -2.05748412e-03,
#         -4.44584200e-03,  1.35633247e-02, -5.05516585e-03, -4.88913292e-03,
#          8.70000198e-03, -3.62336333e-03, -5.56940958e-03, -1.40011776e-04,
#          4.30016982e-04,  3.57366889e-03,  7.24496273e-03,  2.14347057e-03,
#          3.02804844e-03,  5.67771541e-03, -3.84902209e-03, -1.02937222e-03,
#          7.51272356e-03, -2.47028260e-03, -3.68996593e-03,  5.04886452e-03,
#         -4.68300236e-03, -5.33785147e-04,  4.21385095e-03, -4.24088677e-03,
#          7.41485087e-03, -1.21356582e-03, -9.22658131e-04, -4.14614240e-03,
#         -2.96616158e-03, -9.48265754e-03, -4.63053910e-03, -6.52292743e-03,
#         -1.49994856e-02, -6.94034854e-03,  6.41802384e-04, -5.41047053e-03,
#         -6.76630065e-03,  4.47372254e-03, -2.41967128e-03,  8.08679126e-03,
#         -7.30034662e-03, -3.80482897e-03,  1.05328402e-02,  1.47726620e-02,
#          8.08343105e-03,  4.30298550e-03,  2.33330927e-03, -1.07368315e-02,
#          5.27034188e-03,  5.88373793e-03,  2.23274902e-03, -5.40387630e-03,
#         -1.29390124e-03, -2.59725167e-03,  9.36924573e-03,  2.21197261e-03,
#         -8.50358885e-03, -8.86973180e-03, -3.91341222e-04,  1.72111951e-03,
#         -9.79778357e-03, -2.46724323e-03,  9.26133362e-04,  3.29252752e-03,
#          5.65952912e-04,  4.57976619e-03,  2.40955572e-03,  2.37674522e-03,
#          4.29188460e-03, -5.82324760e-03,  4.27084183e-03, -7.99726229e-03,
#          8.27747048e-04,  2.24558311e-03, -8.06868356e-03, -7.73238763e-03,
#          3.87967168e-03,  5.45656262e-03,  6.64277840e-03,  1.82062550e-03,
#         -4.77765501e-03, -7.61187682e-03, -6.61195256e-04,  4.84130485e-03,
#         -1.40391348e-03, -1.11025479e-03, -5.84645662e-03, -1.30023458e-03],
#        dtype=float32),
#  array([ 0.01050566, -0.02743398,  0.03060487,  0.02460284,  0.01727537,
#         -0.01235722, -0.00388567,  0.01516622,  0.00247858,  0.02825338,
#          0.02352393, -0.0011412 , -0.01439745, -0.02851651,  0.0296554 ,
#          0.03409056, -0.02509815,  0.01702852, -0.0252082 ,  0.02791531,
#          0.01633729,  0.00372091, -0.02538227, -0.04644024, -0.04260251,
#          0.01315716, -0.02850091,  0.01710491,  0.00415925,  0.00405768,
#         -0.02039016, -0.00148257,  0.0070499 ,  0.01312146, -0.00542104,
#          0.03115236,  0.03336293, -0.00614858,  0.01716757, -0.00716684,
#         -0.01534967,  0.05024999, -0.01209035, -0.01610473,  0.03707593,
#          0.00054103, -0.02508395,  0.01222117, -0.00334387,  0.01694602,
#          0.03764576, -0.00248463,  0.00992854,  0.0112964 , -0.01066127,
#         -0.00727478,  0.02408084, -0.01211282, -0.02973441,  0.01431737,
#         -0.02322151, -0.00070162,  0.0138104 , -0.01791213,  0.02335963,
#         -0.00535542,  0.01353193, -0.00974221, -0.00324716, -0.02778132,
#         -0.02192011, -0.02634111, -0.05068581, -0.04089087,  0.00476373,
#         -0.03212446, -0.02396903,  0.01026534, -0.01690348,  0.03993553,
#         -0.01911984, -0.02566668,  0.03398084,  0.05959609,  0.02263556,
#          0.01541863,  0.02575158, -0.04448766,  0.01105097,  0.01417203,
#         -0.01441756, -0.01989616,  0.00502973, -0.00812968,  0.04677629,
#          0.00190246, -0.03489326, -0.03927407, -0.00527889, -0.00743163,
#         -0.03414311, -0.00910361, -0.00419991,  0.01384241,  0.00799584,
#          0.00836038,  0.00217807,  0.01683862,  0.01140857, -0.02651366,
#          0.02092871, -0.02283768,  0.00613815,  0.01155982, -0.02884129,
#         -0.01893535,  0.01428076,  0.01491984,  0.02139477,  0.00288161,
#         -0.02123792, -0.02472365, -0.02208403,  0.02172465, -0.01878061,
#         -0.00626274, -0.01333311, -0.00954609], dtype=float32)]

# %% [markdown]
# __NOTE:__ You can also save answer vectors through giving another array keyword. For example: np.savez("/content/sample_data/vector.npz", x=ques_vec, y=ans_vec)

# %% [markdown]
# ## Component 4: vector search

# %% [markdown]
# Vector search is a machine learning technique that uses numeric representations of content to find similar items in a dataset. Cosine similarity measurement is a common way to conduct vector search.
#
# [Faiss](https://github.com/facebookresearch/faiss) is a library for efficient similarity search and clustering of dense vectors. It contains algorithms that search in sets of vectors of any size, up to ones that possibly do not fit in RAM. It also contains supporting code for evaluation and parameter tuning. Faiss is written in C++ with complete wrappers for Python/numpy. Some of the most useful algorithms are implemented on the GPU. It is developed primarily at Meta's Fundamental AI Research group.

# %%
import faiss

# %% [markdown]
# ### FAISS similarity search example

# %%
dataSetI = [.1, .2, .3]
dataSetII = [.4, .5, .6]
#dataSetII = [.1, .2, .3]
dataSetIII = [.4, .5, .7]

x = np.array([dataSetI]).astype(np.float32)
q = np.array([dataSetII]).astype(np.float32)
index = faiss.index_factory(3, "Flat", faiss.METRIC_INNER_PRODUCT)
#index.ntotal
faiss.normalize_L2(x)
index.add(x)
y = np.array([dataSetIII]).astype(np.float32)
faiss.normalize_L2(y)
index.add(y)
faiss.normalize_L2(q)
distance, index = index.search(q, k=index.ntotal)
print('Distance by FAISS:{}'.format(distance))
# Out:
# Distance by FAISS:[[0.9970375 0.9746319]]

# %%
index
# Out:
# array([[1, 0]])

# %%
from scipy import spatial

result = 1 - spatial.distance.cosine(dataSetI, dataSetII)
print('Distance by FAISS:{}'.format(result))
# Out:
# Distance by FAISS:0.9746318461970762

# %% [markdown]
# ### Functions to generate query sentence vector and find matched answer

# %%
def trained_sentence_vec(sent):
    # Filter out terms that are not in the vocabulary from the question sentence
    qu_voc = [tm for tm in sent if tm in w2v.wv]
    # Get the embedding of the characters
    emb = np.vstack([w2v.wv[tm] for tm in qu_voc])
    # Calculate the vectors of each included word to get the vector of the question
    ave_vec = np.mean(emb, axis=0)
    return ave_vec

def find_answer(qr_sentence, ques_vec):
    # use one query sentence to retrieve answer
    qr_sentence = gensim.utils.simple_preprocess(qr_sentence)
    qr_sent_vec = trained_sentence_vec(qr_sentence)

    # perform vector search through similarity comparison
    n_dim = ques_vec.shape[1]
    x = np.vstack(ques_vec).astype(np.float32)
    q = qr_sent_vec.reshape(1, -1)
    index = faiss.index_factory(n_dim, "Flat", faiss.METRIC_INNER_PRODUCT)
    faiss.normalize_L2(x)
    index.add(x)
    faiss.normalize_L2(q)
    similarity, idx = index.search(q, k=index.ntotal)
    ans_idx = idx[0][0]
    return ans_idx

# %%
qr_sentence = "What did Alessandro Volta invent in 1800?"
ans_idx = find_answer(qr_sentence, ques_vec)
print("Query: ", qr_sentence)
print("Question: ", df["Question"][ans_idx])
print("Answer: ", df["Answer"][ans_idx])
# Out:
# Query:  What did Alessandro Volta invent in 1800?
# Question:  What did Alessandro Volta invent in 1800?
# Answer:  In 1800, Alessandro Volta invented the voltaic pile.
